# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
dataset =read_csv('ts2018.csv', index_col='Date', parse_dates=True) 
series = dataset[['Monthly_sales']]

# %%
series.tail()
# Out:
#             Monthly_sales
# Date
# 2018-08-01           1147
# 2018-09-01           1322
# 2018-10-01           1419
# 2018-11-01           1782
# 2018-12-01           1398

# %%
series.plot()
pyplot.show()
